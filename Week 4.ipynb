# %% [markdown]
# ### Data Mining with Weka (Week 4)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime

# %matplotlib inline
sns.set_style('dark')
sns.set(font_scale=1.2)

import warnings
warnings.filterwarnings('ignore')

from sklearn.preprocessing import LabelEncoder, StandardScaler, MinMaxScaler, OneHotEncoder
from sklearn.metrics import confusion_matrix, classification_report, mean_absolute_error, mean_squared_error,r2_score
from sklearn.metrics import plot_confusion_matrix, plot_precision_recall_curve, plot_roc_curve, accuracy_score
from sklearn.metrics import auc, f1_score, precision_score, recall_score, roc_auc_score


from pycaret.regression import *

pd.set_option('display.max_columns',None)
#pd.set_option('display.max_rows',None)

np.random.seed(123)

# %%
cpu = pd.read_csv("cpu.csv")

# %%
cpu
# Out:
#      MYCT  MMIN   MMAX  CACH  CHMIN  CHMAX  class
# 0     125   256   6000   256     16    128    198
# 1      29  8000  32000    32      8     32    269
# 2      29  8000  32000    32      8     32    220
# 3      29  8000  32000    32      8     32    172
# 4      29  8000  16000    32      8     16    132
# ..    ...   ...    ...   ...    ...    ...    ...
# 204   124  1000   8000     0      1      8     42
# 205    98  1000   8000    32      2      8     46
# 206   125  2000   8000     0      2     14     52
# 207   480   512   8000    32      0      0     67
# 208   480  1000   4000     0      0      0     45
#
# [209 rows x 7 columns]

# %%
vendor = pd.read_csv("cpuwithvendor.csv")

# %%
vendor
# Out:
#       vendor  MYCT  MMIN   MMAX  CACH  CHMIN  CHMAX  class
# 0    adviser   125   256   6000   256     16    128    199
# 1     amdahl    29  8000  32000    32      8     32    253
# 2     amdahl    29  8000  32000    32      8     32    253
# 3     amdahl    29  8000  32000    32      8     32    253
# 4     amdahl    29  8000  16000    32      8     16    132
# ..       ...   ...   ...    ...   ...    ...    ...    ...
# 204   sperry   124  1000   8000     0      1      8     37
# 205   sperry    98  1000   8000    32      2      8     50
# 206   sratus   125  2000   8000     0      2     14     41
# 207     wang   480   512   8000    32      0      0     47
# 208     wang   480  1000   4000     0      0      0     25
#
# [209 rows x 8 columns]

# %%
vendor["vendor"].nunique()
# Out:
# 30

# %%
exp_reg101 = setup(data = vendor, target = 'class', session_id=123)
# Out:
#
# Setup Succesfully Completed!
# <style  type="text/css" >
# </style><table id="T_30079346_dad0_11ea_8f00_3c528213d836" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_30079346_dad0_11ea_8f00_3c528213d836level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_30079346_dad0_11ea_8f00_3c528213d836row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_30079346_dad0_11ea_8f00_3c528213d836row0_col1" class="data row0 col1" >123</td>
#             </tr>
#             <tr>
#                         <th id="T_30079346_dad0_11ea_8f00_3c528213d836level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_30079346_dad0_11ea_8f00_3c528213d836row1_col0" class="data row1 col0" >Transform Target </td>
# ...

# %%
lr = create_model('lr')
# Out:
#           MAE         MSE      RMSE      R2   RMSLE    MAPE
# 0     67.3419  11173.9229  105.7068  0.7596  1.0432  1.0061
# 1     32.8959   2015.4843   44.8941  0.7481  0.5753  0.6059
# 2     27.6825   3117.3107   55.8329  0.4733  0.7661  0.4251
# 3     24.1615   1241.2418   35.2313  0.3803  0.7522  0.6445
# 4     53.0203  10471.1259  102.3285  0.8821  0.8611  0.6462
# 5     27.7079   1686.0608   41.0617  0.4860  0.6916  1.0133
# 6     41.7316   3828.4643   61.8746 -1.9131  0.7334  1.0043
# 7     33.9954   2606.2713   51.0517  0.7606  0.6260  0.7076
# 8     54.8584  21783.2330  147.5914  0.6662  0.8991  0.4992
# 9     22.4907    799.7230   28.2794  0.8864  0.5045  0.7653
# Mean  38.5886   5872.2838   67.3852  0.4129  0.7453  0.7318
# SD    14.3796   6359.4475   36.4899  0.7926  0.1518  0.2023

# %%
from pycaret.classification import *

# %%
glass  = pd.read_csv("glass.csv")

# %%
glass
# Out:
#           RI     Na    Mg    Al     Si     K     Ca   Ba    Fe  \
# 0    1.51793  12.79  3.50  1.12  73.03  0.64   8.77  0.0  0.00
# 1    1.51643  12.16  3.52  1.35  72.89  0.57   8.53  0.0  0.00
# 2    1.51793  13.21  3.48  1.41  72.64  0.59   8.43  0.0  0.00
# 3    1.51299  14.40  1.74  1.54  74.55  0.00   7.59  0.0  0.00
# 4    1.53393  12.30  0.00  1.00  70.16  0.12  16.19  0.0  0.24
# ..       ...    ...   ...   ...    ...   ...    ...  ...   ...
# 209  1.51610  13.42  3.40  1.22  72.69  0.59   8.32  0.0  0.00
# 210  1.51592  12.86  3.52  2.12  72.66  0.69   7.97  0.0  0.00
# 211  1.51613  13.92  3.52  1.25  72.88  0.37   7.94  0.0  0.14
# 212  1.51689  12.67  2.88  1.71  73.21  0.73   8.54  0.0  0.00
# 213  1.51852  14.09  2.19  1.66  72.67  0.00   9.32  0.0  0.00
#
#                   Type
# 0       buildwindfloat
# 1       vehicwindfloat
# 2       buildwindfloat
# 3            tableware
# 4    buildwindnonfloat
# ..                 ...
# 209     vehicwindfloat
# ...

# %%
exp_clf1= setup(data = glass, target = 'Type', session_id=123)
# Out:
#
# Setup Succesfully Completed!
# <style  type="text/css" >
# </style><table id="T_d28a064c_dad1_11ea_a1bd_3c528213d836" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d28a064c_dad1_11ea_a1bd_3c528213d836level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_d28a064c_dad1_11ea_a1bd_3c528213d836row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_d28a064c_dad1_11ea_a1bd_3c528213d836row0_col1" class="data row0 col1" >123</td>
#             </tr>
#             <tr>
#                         <th id="T_d28a064c_dad1_11ea_a1bd_3c528213d836level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_d28a064c_dad1_11ea_a1bd_3c528213d836row1_col0" class="data row1 col0" >Target Type</td>
# ...

# %%
compare_models()
# Out:
# <style  type="text/css" >
#     #T_1d7f1712_dad2_11ea_a87a_3c528213d836 th {
#           text-align: left;
#     }    #T_1d7f1712_dad2_11ea_a87a_3c528213d836row0_col0 {
#             text-align:  left;
#         }    #T_1d7f1712_dad2_11ea_a87a_3c528213d836row0_col1 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_1d7f1712_dad2_11ea_a87a_3c528213d836row0_col2 {
#             text-align:  left;
#         }    #T_1d7f1712_dad2_11ea_a87a_3c528213d836row0_col3 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_1d7f1712_dad2_11ea_a87a_3c528213d836row0_col4 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_1d7f1712_dad2_11ea_a87a_3c528213d836row0_col5 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_1d7f1712_dad2_11ea_a87a_3c528213d836row0_col6 {
#             background-color:  yellow;
# ...

# %%
labor= pd.read_csv("labor.csv")

# %%
labor
# Out:
#    duration wage-increase-first-year wage-increase-second-year  \
# 0         1                        5                         ?
# 1         2                      4.5                       5.8
# 2         ?                        ?                         ?
# 3         3                      3.7                         4
# 4         3                      4.5                       4.5
# 5         2                        2                       2.5
# 6         3                        4                         5
# 7         3                      6.9                       4.8
# 8         2                        3                         7
# 9         1                      5.7                         ?
# 10        3                      3.5                         4
# 11        2                      6.4                       6.4
# 12        2                      3.5                         4
# 13        3                      3.5                         4
# ...

# %%
labor.replace(to_replace='?', value=np.nan, inplace=True)

# %%
labor
# Out:
#    duration wage-increase-first-year wage-increase-second-year  \
# 0         1                        5                       NaN
# 1         2                      4.5                       5.8
# 2       NaN                      NaN                       NaN
# 3         3                      3.7                         4
# 4         3                      4.5                       4.5
# 5         2                        2                       2.5
# 6         3                        4                         5
# 7         3                      6.9                       4.8
# 8         2                        3                         7
# 9         1                      5.7                       NaN
# 10        3                      3.5                         4
# 11        2                      6.4                       6.4
# 12        2                      3.5                         4
# 13        3                      3.5                         4
# ...

# %%
exp_clf2= setup(data = labor, target = 'class', session_id=123)
# Out:
#
# Setup Succesfully Completed!
# <style  type="text/css" >
#     #T_70098b70_dad2_11ea_9f8a_3c528213d836row4_col1 {
#             background-color:  lightgreen;
#         }</style><table id="T_70098b70_dad2_11ea_9f8a_3c528213d836" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_70098b70_dad2_11ea_9f8a_3c528213d836level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_70098b70_dad2_11ea_9f8a_3c528213d836row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_70098b70_dad2_11ea_9f8a_3c528213d836row0_col1" class="data row0 col1" >123</td>
#             </tr>
#             <tr>
#                         <th id="T_70098b70_dad2_11ea_9f8a_3c528213d836level0_row1" class="row_heading level0 row1" >1</th>
# ...

# %%
compare_models()
# Out:
# <style  type="text/css" >
#     #T_8da6d82c_dad2_11ea_8f10_3c528213d836 th {
#           text-align: left;
#     }    #T_8da6d82c_dad2_11ea_8f10_3c528213d836row0_col0 {
#             text-align:  left;
#         }    #T_8da6d82c_dad2_11ea_8f10_3c528213d836row0_col1 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_8da6d82c_dad2_11ea_8f10_3c528213d836row0_col2 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_8da6d82c_dad2_11ea_8f10_3c528213d836row0_col3 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_8da6d82c_dad2_11ea_8f10_3c528213d836row0_col4 {
#             : ;
#             text-align:  left;
#         }    #T_8da6d82c_dad2_11ea_8f10_3c528213d836row0_col5 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_8da6d82c_dad2_11ea_8f10_3c528213d836row0_col6 {
#             background-color:  yellow;
# ...

# %%
cancer = pd.read_csv("breastcancer.csv")

# %%
cancer
# Out:
#        age menopause tumor-size inv-nodes node-caps  deg-malig breast  \
# 0    40-49   premeno      15-19       0-2       yes          3  right
# 1    50-59      ge40      15-19       0-2        no          1  right
# 2    50-59      ge40      35-39       0-2        no          2   left
# 3    40-49   premeno      35-39       0-2       yes          3  right
# 4    40-49   premeno      30-34       3-5       yes          2   left
# ..     ...       ...        ...       ...       ...        ...    ...
# 281  50-59      ge40      30-34       6-8       yes          2   left
# 282  50-59   premeno      25-29       3-5       yes          2   left
# 283  30-39   premeno      30-34       6-8       yes          2  right
# 284  50-59   premeno      15-19       0-2        no          2  right
# 285  50-59      ge40      40-44       0-2        no          3   left
#
#     breast-quad irradiat                 Class
# 0       left_up       no     recurrence-events
# ...

# %%
exp_clf3= setup(data = cancer, target = 'Class', session_id=123)
# Out:
#
# Setup Succesfully Completed!
# <style  type="text/css" >
# </style><table id="T_d7ad8e40_dad2_11ea_914d_3c528213d836" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d7ad8e40_dad2_11ea_914d_3c528213d836level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_d7ad8e40_dad2_11ea_914d_3c528213d836row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_d7ad8e40_dad2_11ea_914d_3c528213d836row0_col1" class="data row0 col1" >123</td>
#             </tr>
#             <tr>
#                         <th id="T_d7ad8e40_dad2_11ea_914d_3c528213d836level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_d7ad8e40_dad2_11ea_914d_3c528213d836row1_col0" class="data row1 col0" >Target Type</td>
# ...

# %%
compare_models()
# Out:
# <style  type="text/css" >
#     #T_eec02aee_dad2_11ea_8af6_3c528213d836 th {
#           text-align: left;
#     }    #T_eec02aee_dad2_11ea_8af6_3c528213d836row0_col0 {
#             text-align:  left;
#         }    #T_eec02aee_dad2_11ea_8af6_3c528213d836row0_col1 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_eec02aee_dad2_11ea_8af6_3c528213d836row0_col2 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_eec02aee_dad2_11ea_8af6_3c528213d836row0_col3 {
#             : ;
#             text-align:  left;
#         }    #T_eec02aee_dad2_11ea_8af6_3c528213d836row0_col4 {
#             : ;
#             text-align:  left;
#         }    #T_eec02aee_dad2_11ea_8af6_3c528213d836row0_col5 {
#             : ;
#             text-align:  left;
#         }    #T_eec02aee_dad2_11ea_8af6_3c528213d836row0_col6 {
#             : ;
#             text-align:  left;
# ...
